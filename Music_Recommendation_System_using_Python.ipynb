# %% [markdown]
# <a href="https://colab.research.google.com/github/ovietite/Music-Recommendation-System-using-Python/blob/main/Music_Recommendation_System_using_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import base64

# %%
CLIENT_ID = 'f3ac1efc083b41378b198d09ecc5bfc4'
CLIENT_SECRET = '5a52d054946e42bc8ff5245dbfd3fed6'

# %%
#USE BASE64 TO ENCODE THE VARIABLES HOLDING THE AUTHORIZATION CREDENTILAS
client_credentials = f"{CLIENT_ID}:{CLIENT_SECRET}"
client_credentials_base64 = base64.b64encode(client_credentials.encode())

# %%
#REQUEST THE ACCESS TOKEN
token_url = 'https://accounts.spotify.com/api/token'
headers = {'Authorization' : f'Basic {client_credentials_base64.decode()}'}
data = {'grant_type':'client_credentials'}
response = requests.post(token_url, data = data, headers=headers)

if response.status_code == 200:
  access_token = response.json()['access_token']
  print("Access token obtained successfully.")
else:
  print("Error obtaining access token.")
  exit()
# Out:
# Access token obtained successfully.

# %%
pip install spotipy
# Out:
# Requirement already satisfied: spotipy in /usr/local/lib/python3.10/dist-packages (2.23.0)
# Requirement already satisfied: redis>=3.5.3 in /usr/local/lib/python3.10/dist-packages (from spotipy) (5.0.1)
# Requirement already satisfied: requests>=2.25.0 in /usr/local/lib/python3.10/dist-packages (from spotipy) (2.31.0)
# Requirement already satisfied: six>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from spotipy) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.10/dist-packages (from spotipy) (2.0.6)
# Requirement already satisfied: async-timeout>=4.0.2 in /usr/local/lib/python3.10/dist-packages (from redis>=3.5.3->spotipy) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.0->spotipy) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.0->spotipy) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.0->spotipy) (2023.7.22)

# %%
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyOAuth

def get_trending_playlist_data(playlist_id, access_token):
  #set up spotipy with access token
  sp = spotipy.Spotify(auth=access_token)

  #Get the tracks from the playlist
  playlist_tracks = sp.playlist_tracks(playlist_id, fields='items(track(id,name, artists, album(id, name)))')

  #Extract relevant information and store in a list of dictionaries
  music_data = []
  for track_info in playlist_tracks['items']:
    track = track_info['track']
    track_name = track['name']
    artists = ','.join([artist['name'] for artist in track['artists']])
    album_name = track['album']['name']
    album_id = track['album']['id']
    track_id = track['id']

    #get audio features for the track
    audio_features = sp.audio_features(track_id)[0] if track_id != 'Not available' else None

    #get release date of the album \
    try:
      album_info = sp.album(album_id) if album_id != 'Not available' else None
      release_date = album_info['release_date'] if album_info else None
    except:
      release_date = None

    #get the popularity of the track
    try:
      track_info = sp.track(track_id) if track_id != 'Not available' else None
      popularity = track_info['popularity'] if track_info else None
    except:
      popularity = None

    #Add additional track information to the track data
    track_data={
        'Track Name': track_name,
        'Artists' : artists,
        'Album Name' : album_name,
        'Track ID': track_id,
        'Album ID': album_id,
        'Popularity': popularity,
        'Release Date': release_date,
        'Duration (ms)':audio_features['duration_ms'] if audio_features else None,
        'Explicit': track_info.get('explicit', None),
        'External URLs': track_info.get('external_urls', {}).get('spotify', None),
        'Danceability': audio_features['danceability'] if audio_features else None,
        'Energy': audio_features['energy'] if audio_features else None,
        'Key': audio_features['key'] if audio_features else None,
        'Loudness': audio_features['loudness'] if audio_features else None,
        'Mode': audio_features['mode'] if audio_features else None,
        'Speechiness': audio_features['speechiness'] if audio_features else None,
        'Acousticness': audio_features['acousticness'] if audio_features else None,
        'Instrumentalness': audio_features['instrumentalness'] if audio_features else None,
        'Liveness': audio_features['liveness'] if audio_features else None,
        'Valence': audio_features['valence'] if audio_features else None,
        'Tempo': audio_features['tempo'] if audio_features else None,
    }
    music_data.append(track_data)



  #create a df from the list of dictionaries
  df = pd.DataFrame(music_data)

  return df

# %%
#we then supply the code with our target playlist
playlist_id = '37i9dQZF1EQqFPe2ux3rbj'

music_df = get_trending_playlist_data(playlist_id, access_token)

print(music_df)
# Out:
#                                        Track Name  \
# 0     UNAVAILABLE (feat. Musa Keys) - Latto Remix
# 1                                           Charm
# 2                                       recognize
# 3                        KU LO SA - A COLORS SHOW
# 4                                       Last Last
# 5                                            Sere
# 6        Soweto (with Don Toliver, Rema & Tempoe)
# 7                                   Sip (Alcohol)
# 8                                             Lie
# 9                                            soso
# 10                                          Ngozi
# 11               Sungba (feat. Burna Boy) - Remix
# 12                                           Dior
# 13                                    Electricity
# 14                                          Alone
# 15                                         Jolene
# 16                                           Baby
# 17                                          Peace
# 18                                          Ototo
# 19                                        Stamina
# 20                                      One Woman
# 21                                           Rush
# 22                                        Finesse
# 23                                           Fall
# 24                             All Of Us (Ashawo)
# 25                                    Body & Soul
# 26                                         Loaded
# 27                                      Feel Good
# 28                                          Fever
# 29                                          Lo Lo
# 30                         Overloading (OVERDOSE)
# 31                                          Ma Lo
# 32  PAMI (feat. Wizkid, Adekunle Gold & Omah Lay)
# 33                 Love Don't Cost A Dime (Re-Up)
# 34                              Lonely At The Top
# 35                                  Pour Me Water
# 36                                         Bounce
# 37                                      Vibration
# 38                             KANTE (feat. Fave)
# 39                                           Joro
# 40                                       Ta Ta Ta
# 41                                         PARIWO
# 42                                       All Over
# 43                                          Awodi
# 44                       love nwantiti (ah ah ah)
# 45                            Something Different
# 46                      Infinity (feat. Omah Lay)
# 47                                      Ojuelegba
# 48                                          Diana
# 49                             Personally - Bonus
#
#                                               Artists  \
# 0                              Davido,Musa Keys,Latto
# 1                                                Rema
# 2                                            Omah Lay
# 3                                              Oxlade
# 4                                           Burna Boy
# 5                                 SPINALL,Fireboy DML
# 6                     Victony,Rema,Tempoe,Don Toliver
# 7                                              Joeboy
# 8                                         Kizz Daniel
# 9                                            Omah Lay
# 10                                  Crayon,Ayra Starr
# 11                                    Asake,Burna Boy
# 12                                              Ruger
# 13                                      Pheelz,Davido
# 14                                          Burna Boy
# 15                                      Victony,KTIZO
# 16                                             Joeboy
# 17                                             Mohbad
# 18                                              Asake
# 19                  Tiwa Savage,Ayra Starr,Young Jonn
# 20                        Adekunle Gold,Ty Dolla $ign
# 21                                         Ayra Starr
# 22                                        Pheelz,Bnxn
# 23                                             Davido
# 24                                        Fireboy DML
# 25                                             Joeboy
# 26                                  Tiwa Savage,Asake
# 27                                             Mohbad
# 28                                             Wizkid
# 29                                           Omah Lay
# 30  Mavins,Crayon,Ayra Starr,LADIPOE,Magixx,Boy Spyce
# 31                          Tiwa Savage,Wizkid,Spellz
# 32             DJ Tunez,Wizkid,Adekunle Gold,Omah Lay
# 33                                  Magixx,Ayra Starr
# 34                                              Asake
# 35                                        Kizz Daniel
# 36                                              Ruger
# 37                                        Fireboy DML
# 38                                        Davido,Fave
# 39                                             Wizkid
# 40                                            Bayanni
# 41                               Mohbad,Bella Shmurda
# 42                                             Magixx
# 43                                              Asake
# 44                                               CKay
# 45                                      Adekunle Gold
# 46                                   Olamide,Omah Lay
# 47                                             Wizkid
# 48                   Fireboy DML,Chris Brown,Shenseea
# 49                                           P-Square
#
#                                            Album Name                Track ID  \
# 0         UNAVAILABLE (feat. Musa Keys) [Latto Remix]  29Mf5GsUgU3KLh3lAOGIU3
# 1                                  Rave & Roses Ultra  1iBWjQ9af9NnUd5xnQDB3k
# 2                                           Boy Alone  6ezXpXqbGqIwxUuVBMpHTp
# 3                            KU LO SA - A COLORS SHOW  2WigMwGJysIh9fRnSJvpjn
# 4                                        Love, Damini  5YbPxJwPfrj7uswNwoF1pJ
# 5                                               Grace  35056uy2b4M1qJ3Z1ed3sf
# 6          Soweto (with Don Toliver, Rema and Tempoe)  25Kyv5SeEenT0EETpP2hYn
# 7                                         Body & Soul  4s6x56uNiNCAA87yzqTz5G
# 44  6lheAtw3IcJvflIhLbykih          81   2019-08-30         145800      True
# 45  6GHHoK6LC0Y36nYsouK8qR          54   2020-08-21         175987      True
# 46  6fG2eFCgUmytQWL6umtsCh          69   2020-10-07         171765      True
# 47  3K4CaKaEcLuJkJZ3lATzrq          62   2017-09-17         216243     False
# 48  1pUJnA3OSbvVr5afqxNARZ          67   2022-08-04         232156      True
# 49  1sVtq235BmEjpt3yWYM9pR          56   2014-09-12         192885     False
#
#                                         External URLs  ...  Energy  Key  \
# 0   https://open.spotify.com/track/29Mf5GsUgU3KLh3...  ...   0.669    0
# 1   https://open.spotify.com/track/1iBWjQ9af9NnUd5...  ...   0.663    4
# 2   https://open.spotify.com/track/6ezXpXqbGqIwxUu...  ...   0.140   10
# 3   https://open.spotify.com/track/2WigMwGJysIh9fR...  ...   0.655   10
# 4   https://open.spotify.com/track/5YbPxJwPfrj7usw...  ...   0.565    3
# 5   https://open.spotify.com/track/35056uy2b4M1qJ3...  ...   0.679    7
# 6   https://open.spotify.com/track/25Kyv5SeEenT0EE...  ...   0.756    5
# 7   https://open.spotify.com/track/4s6x56uNiNCAA87...  ...   0.615   10
# 8   https://open.spotify.com/track/03DxO8kGNrEGr1V...  ...   0.633    6
# 9   https://open.spotify.com/track/1wADwLSkYhrSmy4...  ...   0.725    3
# 10  https://open.spotify.com/track/5mhM7bfzv52bzfC...  ...   0.428    6
# 11  https://open.spotify.com/track/4k4pdUWX8632g7y...  ...   0.611    7
# 12  https://open.spotify.com/track/6nLdg1lpE3dHLmN...  ...   0.539    7
# 13  https://open.spotify.com/track/5ZGXOgSHLkDYlDs...  ...   0.720    9
# 14  https://open.spotify.com/track/0AoBY2Y3qs6dtGg...  ...   0.659    4
# 15  https://open.spotify.com/track/5483pcvbfX7Ii7g...  ...   0.683    4
# 16  https://open.spotify.com/track/0Yz6pPFinS7EKfa...  ...   0.806   11
# 17  https://open.spotify.com/track/0ESoMa1oGHddkMe...  ...   0.740   11
# 18  https://open.spotify.com/track/0CUJV0Hh512Ns7U...  ...   0.580    0
# 19  https://open.spotify.com/track/1tOp1bXhT9tvydS...  ...   0.631    8
# 20  https://open.spotify.com/track/7BglTfVmbUUOCQU...  ...   0.526    6
# 21  https://open.spotify.com/track/1xs8bOvm3IzEYmc...  ...   0.503    1
# 22  https://open.spotify.com/track/45lKz9WsEol7FEV...  ...   0.537    1
# 23  https://open.spotify.com/track/1hEXElwyPez2z7m...  ...   0.675    5
# 24  https://open.spotify.com/track/6459gZKddpOoPIH...  ...   0.813   11
# 25  https://open.spotify.com/track/2AaZJAh9FifPCQd...  ...   0.666    6
# 26  https://open.spotify.com/track/3J5IO8OLj05dRaZ...  ...   0.710    9
# 27  https://open.spotify.com/track/0int0g8dikLn0uh...  ...   0.841    8
# 28  https://open.spotify.com/track/5mN3xSyvCmFy1jk...  ...   0.806    0
# 29  https://open.spotify.com/track/20hZEnFjyvUIk4Y...  ...   0.704    7
# 30  https://open.spotify.com/track/3ES1fBQACydIODl...  ...   0.611    0
# 31  https://open.spotify.com/track/6U9jxxdQ6TNzjsh...  ...   0.721   11
# 32  https://open.spotify.com/track/6iC4xfqow6iAsRh...  ...   0.645    3
# 33  https://open.spotify.com/track/0hW02S9ACVYANz1...  ...   0.571    8
# 34  https://open.spotify.com/track/5ZtK8XAVnoaGdBX...  ...   0.801    6
# 35  https://open.spotify.com/track/1DrfpnLvbwndPSc...  ...   0.708    8
# 36  https://open.spotify.com/track/3ku51L937DfBoNc...  ...   0.709    1
# 37  https://open.spotify.com/track/7u0z6FcJDqkZwdp...  ...   0.828   11
# 38  https://open.spotify.com/track/7vKXc90NT5WBm3U...  ...   0.809    6
# 39  https://open.spotify.com/track/3Yt1ovsh3v3VEzR...  ...   0.694    7
# 40  https://open.spotify.com/track/3rmqNsOiGqqvFNT...  ...   0.592    1
# 41  https://open.spotify.com/track/35UGCXaOBmhBUmK...  ...   0.636    7
# 42  https://open.spotify.com/track/394IT4yrYjwT65e...  ...   0.516    6
# 43  https://open.spotify.com/track/6HM0LR6LKWCqP2v...  ...   0.567   10
# 44  https://open.spotify.com/track/2Xr1dTzJee307rm...  ...   0.739    8
# 45  https://open.spotify.com/track/7g2j8MYcb4PJsI2...  ...   0.829    3
# 46  https://open.spotify.com/track/5DS9LiyEdw2zY8b...  ...   0.535    7
# 47  https://open.spotify.com/track/1AtBzcUzKLh4BGw...  ...   0.748    9
# 48  https://open.spotify.com/track/6g8vNyogMW32lhH...  ...   0.357    2
# 49  https://open.spotify.com/track/4n3aYkOV10dY0d3...  ...   0.734    6
#
#     Loudness  Mode  Speechiness  Acousticness  Instrumentalness  Liveness  \
# 0     -9.490     1       0.0766        0.2470          0.000498    0.1190
# 1     -6.901     0       0.0355        0.5810          0.000000    0.0974
# 2    -11.525     0       0.0883        0.9210          0.091800    0.0968
# 3     -5.534     0       0.0652        0.3070          0.000000    0.2200
# 4     -4.457     0       0.0948        0.1310          0.000000    0.0802
# 5     -6.261     0       0.1080        0.0770          0.000014    0.1420
# 6     -5.392     0       0.0761        0.0541          0.000000    0.1090
# 7     -7.033     0       0.1370        0.4040          0.000000    0.0987
# 8     -6.675     1       0.2940        0.5110          0.003370    0.0927
# 9     -8.315     0       0.0941        0.4240          0.129000    0.1100
# 10   -14.557     1       0.2470        0.0335          0.000006    0.0623
# 11    -8.457     1       0.2230        0.0921          0.000004    0.0321
# 12    -6.704     1       0.2150        0.1640          0.022600    0.0633
# 13    -3.868     1       0.0670        0.0348          0.000000    0.1010
# 14    -7.264     0       0.0542        0.1760          0.000000    0.1110
# 15    -6.123     0       0.0497        0.3610          0.011700    0.2820
# 16    -5.340     1       0.0558        0.1420          0.000285    0.1470
# 17    -5.195     1       0.2830        0.3340          0.015400    0.1100
# 18    -7.924     0       0.0780        0.3820          0.000361    0.4030
# 19    -7.619     1       0.2280        0.3140          0.000000    0.1070
# 20    -5.311     0       0.2310        0.3670          0.000099    0.0760
# 21    -8.044     1       0.0626        0.0369          0.000570    0.0959
# 22    -8.199     0       0.1590        0.5040          0.000000    0.2890
# 23    -3.542     1       0.0568        0.3860          0.000000    0.0564
# 24    -6.416     1       0.0903        0.3040          0.003300    0.1320
# 25    -4.487     1       0.0357        0.3410          0.000033    0.1850
# 26    -7.125     0       0.0643        0.0898          0.000000    0.1350
# 27    -5.208     1       0.1250        0.1090          0.002640    0.0893
# 28    -4.618     0       0.0479        0.5440          0.000114    0.0908
# 29    -4.592     1       0.2510        0.0636          0.163000    0.0991
# 30    -9.459     0       0.1720        0.4840          0.001490    0.1010
# 31    -4.577     1       0.1520        0.4240          0.000003    0.0897
# 32    -6.933     0       0.0944        0.6250          0.000006    0.1970
# 33    -8.252     1       0.2760        0.4350          0.000000    0.0996
# 34    -7.326     0       0.1060        0.6920          0.000155    0.0912
# 35    -6.416     1       0.3780        0.5630          0.005220    0.1250
# 36    -5.961     0       0.0928        0.3140          0.000000    0.1110
# 37    -6.908     1       0.0477        0.4660          0.000012    0.1090
# 38    -5.022     0       0.0929        0.1820          0.000000    0.0765
# 39    -3.693     0       0.2570        0.2530          0.000904    0.1090
# 40   -11.208     1       0.0534        0.0661          0.522000    0.1250
# 41    -7.731     0       0.0632        0.2620          0.000551    0.1530
# 42    -9.995     1       0.2130        0.4340          0.000043    0.1240
# 43    -8.076     0       0.1630        0.1350          0.000000    0.1870
# 44    -3.805     1       0.0411        0.3650          0.001370    0.1610
# 45    -2.420     0       0.1340        0.4530          0.000002    0.1140
# 46    -8.755     0       0.1110        0.3030          0.020100    0.1460
# 47    -5.888     0       0.0351        0.1540          0.000283    0.2390
# 48    -7.735     0       0.0372        0.0695          0.000084    0.1100
# 49    -4.370     0       0.3280        0.0824          0.000572    0.1130
#
#     Valence    Tempo
# 0     0.315  113.022
# 1     0.559   96.039
# 2     0.609  128.921
# 3     0.793   92.900
# 4     0.550   87.925
# 5     0.642  109.971
# 6     0.647  105.024
# 7     0.816  100.058
# 8     0.738  201.726
# 9     0.530  105.016
# 10    0.503  115.029
# 11    0.712  111.984
# 12    0.809  196.054
# 13    0.496  110.968
# 14    0.307   89.955
# 15    0.248  109.957
# 16    0.539  105.001
# 17    0.749  121.073
# 18    0.886  130.672
# 19    0.794  108.783
# 20    0.953   98.241
# 21    0.381   99.970
# 22    0.769  102.014
# 23    0.794  105.953
# 24    0.748  199.837
# 25    0.512  101.012
# 26    0.616  114.061
# 27    0.719  117.997
# 28    0.892   98.008
# 29    0.483  204.004
# 30    0.749  104.059
# 31    0.653  105.230
# 32    0.695   99.889
# 33    0.551  100.210
# 34    0.914  104.986
# 35    0.677  126.883
# 36    0.642   98.008
# 37    0.883  103.983
# 38    0.606   99.005
# 39    0.587  189.998
# 40    0.603  104.065
# 41    0.764  106.997
# 42    0.639  100.018
# 43    0.517  114.000
# 44    0.533   93.005
# 45    0.702   99.467
# 46    0.518  102.017
# 47    0.903  100.056
# 48    0.524  108.946
# 49    0.964  162.463
#
# [50 rows x 21 columns]

# %%
#checking if there is null data
print(music_df.isnull().sum())
# Out:
# Track Name          0
# Artists             0
# Album Name          0
# Track ID            0
# Album ID            0
# Popularity          0
# Release Date        0
# Duration (ms)       0
# Explicit            0
# External URLs       0
# Danceability        0
# Energy              0
# Key                 0
# Loudness            0
# Mode                0
# Speechiness         0
# Acousticness        0
# Instrumentalness    0
# Liveness            0
# Valence             0
# Tempo               0
# dtype: int64

# %%
#importing the neccessary libraries
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from datetime import datetime
from sklearn.metrics.pairwise import cosine_similarity

data = music_df

# %%
# Function to calculate weighted popularity scores based on release date
def calculate_weighted_popularity(release_date):
    # Convert the release date to datetime object
    release_date = datetime.strptime(release_date, '%Y-%m-%d')

    # Calculate the time span between release date and today's date
    time_span = datetime.now() - release_date

    # Calculate the weighted popularity score based on time span (e.g., more recent releases have higher weight)
    weight = 1 / (time_span.days + 1)
    return weight

# %%
# Normalize the music features using Min-Max scaling
scaler = MinMaxScaler()
music_features = music_df[['Danceability', 'Energy', 'Key',
                           'Loudness', 'Mode', 'Speechiness', 'Acousticness',
                           'Instrumentalness', 'Liveness', 'Valence', 'Tempo']].values
music_features_scaled = scaler.fit_transform(music_features)

# %%
# a function to get content-based recommendations based on music features
def content_based_recommendations(input_song_name, num_recommendations=5):
    if input_song_name not in music_df['Track Name'].values:
        print(f"'{input_song_name}' not found in the dataset. Please enter a valid song name.")
        return

    # Get the index of the input song in the music DataFrame
    input_song_index = music_df[music_df['Track Name'] == input_song_name].index[0]

    # Calculate the similarity scores based on music features (cosine similarity)
    similarity_scores = cosine_similarity([music_features_scaled[input_song_index]], music_features_scaled)

    # Get the indices of the most similar songs
    similar_song_indices = similarity_scores.argsort()[0][::-1][1:num_recommendations + 1]

    # Get the names of the most similar songs based on content-based filtering
    content_based_recommendations = music_df.iloc[similar_song_indices][['Track Name', 'Artists', 'Album Name', 'Release Date', 'Popularity']]

    return content_based_recommendations

# %%
# a function to get hybrid recommendations based on weighted popularity
def hybrid_recommendations(input_song_name, num_recommendations=5, alpha=0.5):
    if input_song_name not in music_df['Track Name'].values:
        print(f"'{input_song_name}' not found in the dataset. Please enter a valid song name.")
        return

    # Get content-based recommendations
    content_based_rec = content_based_recommendations(input_song_name, num_recommendations)

    # Get the popularity score of the input song
    popularity_score = music_df.loc[music_df['Track Name'] == input_song_name, 'Popularity'].values[0]

    # Calculate the weighted popularity score
    weighted_popularity_score = popularity_score * calculate_weighted_popularity(music_df.loc[music_df['Track Name'] == input_song_name, 'Release Date'].values[0])

    # Combine content-based and popularity-based recommendations based on weighted popularity
    hybrid_recommendations = content_based_rec
    hybrid_recommendations = hybrid_recommendations.append({
        'Track Name': input_song_name,
        'Artists': music_df.loc[music_df['Track Name'] == input_song_name, 'Artists'].values[0],
        'Album Name': music_df.loc[music_df['Track Name'] == input_song_name, 'Album Name'].values[0],
        'Release Date': music_df.loc[music_df['Track Name'] == input_song_name, 'Release Date'].values[0],
        'Popularity': weighted_popularity_score
    }, ignore_index=True)

    # Sort the hybrid recommendations based on weighted popularity score
    hybrid_recommendations = hybrid_recommendations.sort_values(by='Popularity', ascending=False)

    # Remove the input song from the recommendations
    hybrid_recommendations = hybrid_recommendations[hybrid_recommendations['Track Name'] != input_song_name]


    return hybrid_recommendations

# %%
#test scenerio

input_song_name = "Lonely At The Top"
recommendations = hybrid_recommendations(input_song_name, num_recommendations=3)
print(f"Hybrid recommended songs for '{input_song_name}':")
print(recommendations)
# Out:
# Hybrid recommended songs for 'Lonely At The Top':
#                                       Track Name  \
# 1                                          Charm
# 2                                         PARIWO
# 0  PAMI (feat. Wizkid, Adekunle Gold & Omah Lay)
#
#                                   Artists  \
# 1                                    Rema
# 2                    Mohbad,Bella Shmurda
# 0  DJ Tunez,Wizkid,Adekunle Gold,Omah Lay
#
#                                       Album Name Release Date  Popularity
# 1                             Rave & Roses Ultra   2023-04-27        77.0
# 2                                        Blessed   2023-06-30        66.0
# 0  PAMI (feat. Wizkid, Adekunle Gold & Omah Lay)   2020-08-13        58.0
# <ipython-input-30-3de633f34e34>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   hybrid_recommendations = hybrid_recommendations.append({
